# %% [markdown]
# # MRI QA Agent Prototype
#
# This notebook demonstrates a prototype for an AI agent that can answer questions about Medical Resonance Imaging (MRI) studies.
#
# ## Setup Requirements
#
# Before running this notebook, you need to set up your Google AI API key:
#
# 1. **Get a Google AI API Key:**
#    - Go to [Google AI Studio](https://aistudio.google.com/app/apikey)
#    - Create a new API key
#    - Copy the API key
#
# 2. **Set Environment Variable:**
#    ```bash
#    export GEMINI_API_KEY="your-api-key-here"
#    ```
#
# 3. **Alternative: Set in notebook** (less secure, for testing only):
#    - Uncomment and fill in the API key in the setup cell below
#
# ## Project Overview
#
# This notebook will develop:
# - Basic integration with Google's Gemini AI
# - MRI-specific question processing
# - Medical image analysis capabilities
# - Quality assurance workflows

# %%
import os
import sys

# Check if API key is available
api_key = os.getenv('GEMINI_API_KEY')

if not api_key:
    print("⚠️  GEMINI_API_KEY environment variable not found!")
    print("Setting API key from your .bashrc configuration...")
    
    # Set the API key directly (this is the key from your .bashrc)
    api_key = "YOUR_API_KEY"
    
    if api_key:
        print("✅ API key set successfully")
        print(f"   Key preview: {api_key[:8]}...")
    else:
        print("❌ Cannot proceed without API key")
        sys.exit(1)
else:
    print("✅ GEMINI_API_KEY found")
    print(f"   Key preview: {api_key[:8]}...")

# Set the environment variable for this session
os.environ['GEMINI_API_KEY'] = api_key
print("🔧 Environment variable set for this notebook session")
# Out:
# ✅ GEMINI_API_KEY found
#    Key preview: AIzaSyBW...
# 🔧 Environment variable set for this notebook session

# %%
# !pip install -q -U google-genai

# %%
from google import genai

# Verify API key is available
api_key = os.getenv('GEMINI_API_KEY')
if not api_key:
    raise ValueError("GEMINI_API_KEY environment variable is required. Please run the setup cell above.")

print("🔌 Initializing Google AI client...")

try:
    # The client gets the API key from the environment variable `GEMINI_API_KEY`
    client = genai.Client(api_key=api_key)
    print("✅ Google AI client initialized successfully")
    
    # Test with a simple query
    print("\n🧠 Testing AI connection...")
    response = client.models.generate_content(
        model="gemini-2.5-flash", 
        contents="Explain how AI works in one sentence."
    )
    print(f"✅ AI Response: {response.text}")
    
except Exception as e:
    print(f"❌ Error initializing client: {e}")
    print("Please check your API key and internet connection")
# Out:
# 🔌 Initializing Google AI client...
# ✅ Google AI client initialized successfully
#
# 🧠 Testing AI connection...
# ✅ AI Response: AI works by analyzing vast amounts of data to learn patterns and make predictions or decisions.

# %%
# MRI QA Agent Functions

def ask_mri_question(question, context=""):
    """
    Ask a question about MRI studies with optional context.
    
    Args:
        question (str): The question about MRI
        context (str): Additional context about the MRI study
    
    Returns:
        str: AI response about the MRI question
    """
    
    # Create a prompt optimized for MRI questions
    prompt = f"""
    You are a medical imaging expert specializing in MRI (Magnetic Resonance Imaging) quality assurance.
    Please provide accurate, professional answers about MRI studies.
    
    Context: {context if context else "General MRI question"}
    
    Question: {question}
    
    Please provide a clear, accurate answer focusing on:
    - Technical accuracy
    - Clinical relevance
    - Quality assurance aspects
    - Safety considerations when applicable
    """
    
    try:
        response = client.models.generate_content(
            model="gemini-2.5-flash",
            contents=prompt
        )
        return response.text
    except Exception as e:
        return f"Error getting response: {e}"

# Test the MRI QA function
print("🧬 Testing MRI QA Agent...")
print("=" * 50)

# Test question 1
question1 = "What are the key quality metrics to check in an MRI brain scan?"
answer1 = ask_mri_question(question1)
print(f"Question: {question1}")
print(f"Answer: {answer1}")
print()

# Test question 2
question2 = "How do you identify motion artifacts in MRI images?"
answer2 = ask_mri_question(question2)
print(f"Question: {question2}")
print(f"Answer: {answer2}")
print()
# Out:
# 🧬 Testing MRI QA Agent...
# ==================================================
# Question: What are the key quality metrics to check in an MRI brain scan?
# Answer: As an MRI quality assurance expert, assessing an MRI brain scan involves a systematic evaluation of various technical and clinical metrics to ensure diagnostic accuracy and patient safety. Here are the key quality metrics:
#
# ---
#
# ### Key Quality Metrics for an MRI Brain Scan:
#
# **I. Fundamental Image Quality Metrics (Technical Accuracy & Clinical Relevance)**
#
# 1.  **Signal-to-Noise Ratio (SNR):**
#     *   **Definition:** The ratio of the magnitude of the signal to the magnitude of the noise in the image. High SNR means a clear image with less grainy appearance.
#     *   **QA Aspect:** Evaluated visually for sufficient signal and minimal background noise. Influenced by field strength, coil type, TR/TE, NEX (number of excitations), and voxel size. Low SNR can obscure small lesions or fine anatomical details.
#     *   **Clinical Relevance:** Essential for detecting subtle pathology, particularly in white matter, gray matter, and deep brain structures.
#
# 2.  **Contrast-to-Noise Ratio (CNR):**
#     *   **Definition:** The difference in signal intensity between two adjacent tissue types, relative to the background noise.
#     *   **QA Aspect:** Assessed by the clear differentiation between various brain tissues (e.g., gray matter vs. white matter, CSF vs. brain parenchyma, lesion vs. normal tissue). Optimized by sequence choice (T1, T2, FLAIR, diffusion), TE/TR, and contrast agent administration (if applicable).
#     *   **Clinical Relevance:** Crucial for lesion detection, characterization (e.g., demyelination vs. tumor vs. stroke), and delineation of anatomical boundaries.
#
# 3.  **Spatial Resolution:**
#     *   **Definition:** The ability to distinguish two separate points or structures as distinct. Determined by voxel size (field of view, matrix size, slice thickness).
#     *   **QA Aspect:** Visually check for sharpness and clarity of fine anatomical structures (e.g., cortical sulci, brainstem nuclei, cranial nerves). Thinner slices and smaller in-plane voxels improve resolution but can decrease SNR or increase scan time.
#     *   **Clinical Relevance:** Important for identifying small lesions, microhemorrhages, or subtle anatomical variants, particularly in areas like the pituitary gland, internal auditory canals, or brainstem.
#
# 4.  **Image Uniformity:**
#     *   **Definition:** Consistency of signal intensity across the entire field of view within the same tissue type.
#     *   **QA Aspect:** Look for even signal distribution. Non-uniformity can indicate issues with RF coil performance, shimming (B0 field homogeneity), or gradient system.
#     *   **Clinical Relevance:** Ensures accurate signal interpretation across the entire brain, preventing misdiagnosis due to artificial brightening or darkening in certain regions.
#
# **II. Geometric Accuracy & Coverage (Technical Accuracy & Clinical Relevance)**
#
# 5.  **Slice Positioning and Orientation:**
#     *   **Definition:** Accurate alignment of slices with anatomical planes (axial, sagittal, coronal) or oblique orientations tailored to specific structures (e.g., hippocampus, optic nerves).
#     *   **QA Aspect:** Review scout images and ensure that prescribed slices fully cover the area of interest without truncation of critical structures (e.g., vertex, cerebellum, brainstem). Consistent slice orientation facilitates follow-up comparisons.
#     *   **Clinical Relevance:** Crucial for accurate localization of pathology, surgical planning, and precise measurement of lesions. Inaccurate positioning can lead to missed pathology or misinterpretation of its true extent.
#
# 6.  **Full Brain Coverage:**
#     *   **Definition:** Ensuring the entire brain, from the foramen magnum to the vertex, is included in all necessary sequences.
#     *   **QA Aspect:** Systematically check all series to confirm no parts of the brain are cut off, especially the cerebellum, posterior fossa, or superior convexity.
#     *   **Clinical Relevance:** Prevents missing incidental findings or primary pathology outside the initially suspected area.
#
# 7.  **Geometric Distortion:**
#     *   **Definition:** Inaccuracy in the spatial representation of structures due to magnetic field non-uniformities or gradient non-linearity.
#     *   **QA Aspect:** Visually check for stretching, compression, or warping of structures that should be geometrically true (e.g., ventricles, sulci). Most prominent near air-tissue interfaces or metallic implants.
#     *   **Clinical Relevance:** Essential for accurate lesion measurement, stereotactic planning, and neuronavigation. Significant distortion can lead to mislocalization of pathology.
#
# **III. Artifact Management (Technical Accuracy & Clinical Relevance)**
#
# 8.  **Motion Artifacts:**
#     *   **Definition:** Blurring, ghosting, or streaking caused by patient movement during data acquisition.
#     *   **QA Aspect:** The most common and detrimental artifact. Assessed by examining the sharpness of brain edges, vessels, and the absence of redundant images (ghosts). Patient cooperation, immobilization (head coils, padding), and shorter sequences are key.
#     *   **Clinical Relevance:** Significantly degrades all other quality metrics, making studies non-diagnostic or leading to false positives/negatives.
#
# 9.  **Susceptibility Artifacts:**
#     *   **Definition:** Signal loss (dark areas) or distortion caused by local magnetic field inhomogeneities, often near air-tissue interfaces (e.g., paranasal sinuses, mastoid air cells) or metallic implants.
#     *   **QA Aspect:** Observe for dark signal voids, especially in the orbitofrontal, temporal pole, or posterior fossa regions. Optimized by using specific sequences (e.g., fast spin echo, shorter TE) or adjusting slice angulation.
#     *   **Clinical Relevance:** Can obscure pathology in critical areas or mimic hemorrhage, requiring careful interpretation and potentially alternative sequences.
#
# 10. **Wrap-around (Aliasing) Artifacts:**
#     *   **Definition:** Structures outside the field of view (FOV) are folded back into the image.
#     *   **QA Aspect:** Check for redundant anatomy appearing on the opposite side of the image. Managed by increasing the FOV or using oversampling techniques.
#     *   **Clinical Relevance:** Can obscure true anatomy or pathology within the brain, leading to misinterpretation.
#
# 11. **RF Interference / Zipper Artifacts:**
#     *   **Definition:** Straight lines or bands across the image, caused by external radiofrequency noise leaking into the scan room.
#     *   **QA Aspect:** Check for fine, often diagonal, lines. Indicates issues with RF shielding in the scan room or equipment.
#     *   **Clinical Relevance:** Degrades overall image quality and can obscure subtle findings.
#
# **IV. Clinical Utility & Interpretation (Clinical Relevance & QA Aspects)**
#
# 12. **Protocol Adherence:**
#     *   **Definition:** Whether the appropriate sequences (e.g., T1, T2, FLAIR, DWI, SWI, MRA, contrast-enhanced) were acquired based on the clinical indication.
#     *   **QA Aspect:** Review the prescribed protocol against the clinical question and ensure all necessary sequences are present and technically adequate.
#     *   **Clinical Relevance:** A well-designed protocol ensures that the specific clinical question (e.g., stroke, tumor, multiple sclerosis) is adequately addressed, preventing the need for repeat scans.
#
# 13. **Completeness of Study:**
#     *   **Definition:** All required images are present, correctly labeled, and in the appropriate series/folders for efficient review by the radiologist.
#     *   **QA Aspect:** Ensure all planned acquisitions have successfully completed and transferred to PACS.
#     *   **Clinical Relevance:** Facilitates efficient interpretation and reporting by the radiologist.
#
# **V. Patient & Safety Considerations (Safety & QA Aspects)**
#
# 14. **Patient Comfort and Cooperation:**
#     *   **Definition:** The patient's ability to remain still and follow instructions throughout the scan.
#     *   **QA Aspect:** Directly impacts motion artifacts. Technologists monitor patient comfort, provide clear instructions, and utilize immobilization devices as needed.
#     *   **Clinical Relevance:** Essential for obtaining a high-quality, motion-free study and ensuring a positive patient experience.
#
# 15. **Safety Screening and Monitoring:**
#     *   **Definition:** Ensuring thorough pre-scan safety screening (implants, claustrophobia, allergies) and monitoring of physiological parameters (e.g., SAR levels, acoustic noise).
#     *   **QA Aspect:** Strict adherence to safety protocols for implants, contrast administration, and managing acoustic noise (hearing protection).
#     *   **Clinical Relevance:** Paramount to prevent patient injury (e.g., burns from implants, adverse contrast reactions, hearing damage) and ensure a safe scanning environment.
#
# ---
#
# Effective MRI brain scan quality assurance is a collaborative effort involving the MRI technologist (who acquires the images and monitors the patient), the radiologist (who interprets the images and provides feedback on quality), and medical physicists (who perform routine equipment performance checks). This multi-faceted approach ensures that MRI studies are not only diagnostically valuable but also performed safely and efficiently.
#
# Question: How do you identify motion artifacts in MRI images?
# Answer: As an MRI quality assurance specialist, identifying motion artifacts is paramount for ensuring diagnostic accuracy and optimizing patient care. Motion artifacts are a common challenge in MRI, degrading image quality and potentially obscuring pathology. They arise from any patient movement, whether voluntary (e.g., restlessness, swallowing) or involuntary (e.g., breathing, cardiac pulsations, CSF flow, bowel peristalsis) during data acquisition.
#
# Here's how to identify motion artifacts in MRI images, focusing on technical accuracy, clinical relevance, and quality assurance:
#
# ### How to Identify Motion Artifacts in MRI Images
#
# Motion artifacts manifest in several distinct ways, primarily in the **phase-encode direction** (as phase information is more sensitive to changes over time than frequency information).
#
# 1.  **Blurring:**
#     *   **Appearance:** The most common manifestation. Images appear diffusely hazy, unfocused, or lacking sharp detail. Fine anatomical structures (e.g., small vessels, thin cartilage, cortical gray-white matter junction) lose their crispness and distinct boundaries.
#     *   **Identification:** Look for a general loss of resolution across the image, rather than a localized blur. It affects the entire image or large portions of it.
#     *   **Technical Note:** Often seen with continuous, low-amplitude motion (e.g., subtle patient shifting).
#
# 2.  **Ghosting:**
#     *   **Appearance:** Replicated or "ghost" images of high-signal structures (like fat or flowing blood) appearing repeatedly along the phase-encode direction. These "ghosts" are often weaker in signal than the primary anatomy.
#     *   **Identification:** Observe patterns of identical structures appearing at regular intervals away from their true anatomical location. For example, if the chest wall is in the anterior-posterior phase-encode direction, you might see faint ribs or lung tissue "ghosts" extending into the abdomen.
#     *   **Common Causes:** Physiological motion like breathing (abdominal/chest wall motion), cardiac pulsations (aorta, heart walls), or pulsatile blood flow. The frequency of the ghosts directly relates to the frequency of the physiological motion.
#
# 3.  **Streaking:**
#     *   **Appearance:** Linear bright or dark lines extending across the image, often from a high-signal intensity source. They can be diffuse or appear as discrete lines.
#     *   **Identification:** Look for straight lines that don't conform to anatomical boundaries. These are often seen emanating from rapidly flowing blood (e.g., carotid arteries in brain imaging) or from very rapid, discrete movements (e.g., a sudden cough or swallow during an acquisition).
#
# 4.  **Loss of Definition/Detail:**
#     *   **Appearance:** Small structures that should be clearly delineated (e.g., optic nerves, cranial nerves, small lesions, joint menisci) become indistinct or completely disappear. Borders of organs or lesions become irregular or ill-defined.
#     *   **Identification:** Compare the affected areas with expected normal anatomy or previous unaffected sequences. If expected fine detail is absent or smeared, motion is a likely culprit.
#
# 5.  **Smearing/Shearing:**
#     *   **Appearance:** The image appears stretched, compressed, or distorted in one specific direction, often the phase-encode direction.
#     *   **Identification:** Whole anatomical regions might look elongated or squeezed. Less common than blurring or ghosting, but indicates more significant, often non-periodic, motion during the acquisition.
#
# ### Clinical Relevance of Identifying Motion Artifacts
#
# *   **Diagnostic Ambiguity:** Motion artifacts can obscure true pathology, mimicking or hiding lesions. A small tumor might be blurred out, or a ghost artifact might be mistaken for a lesion.
# *   **Misdiagnosis/Missed Diagnosis:** Failure to recognize or account for artifacts can lead to incorrect diagnoses, resulting in inappropriate treatment or delayed essential interventions.
# *   **Reduced Diagnostic Confidence:** Even if a diagnosis is eventually made, the presence of artifacts reduces the radiologist's confidence in the findings, potentially leading to unnecessary follow-up scans or invasive procedures.
# *   **Compromised Measurements:** Accurate measurements of lesion size, volume, or signal characteristics become unreliable with significant motion.
#
# ### Quality Assurance (QA) Aspects
#
# Identifying motion artifacts is a critical component of MRI quality assurance at several levels:
#
# 1.  **Technologist's Role (First Line of Defense):**
#     *   **Real-time Monitoring:** Experienced technologists constantly monitor the patient and the images being acquired. Many modern scanners provide real-time feedback on image quality, allowing immediate recognition of motion.
#     *   **Patient Communication:** Proactive patient preparation, clear instructions, and reassurance are key to minimizing voluntary motion.
#     *   **Immobilization:** Proper use of coils, pads, straps, and comfort devices to secure the patient.
#     *   **Sequence Optimization:** Employing motion-robust sequences (e.g., PROPELLER/BLADE, EPI, radial k-space sampling), using navigators, respiratory gating/triggering, or shorter acquisition times.
#     *   **Rescanning:** If significant motion is detected during acquisition, the technologist must determine if the sequence needs to be repeated immediately to ensure diagnostic quality. This minimizes patient return visits.
#
# 2.  **Radiologist/Interpreting Physician's Role:**
#     *   **Critical Review:** Radiologists meticulously evaluate image quality as part of their interpretation process. They must differentiate true pathology from artifact.
#     *   **Feedback Loop:** Providing clear feedback to technologists regarding image quality issues helps in continuous improvement of acquisition protocols and patient management strategies.
#
# 3.  **Systemic QA Programs:**
#     *   **Trend Analysis:** Monitoring the incidence of motion artifacts over time can highlight areas for improvement, such as staff training needs, equipment issues, or protocol adjustments.
#     *   **Protocol Review:** Regularly reviewing and updating MRI protocols to incorporate the latest motion suppression techniques.
#     *   **Education:** Ensuring all personnel involved in MRI understand the causes, appearance, and mitigation strategies for motion artifacts.
#
# ### Safety Considerations
#
# While motion artifacts are not a direct safety hazard, their impact has significant indirect safety implications:
#
# *   **Misdiagnosis/Delayed Diagnosis:** As discussed, this is the primary safety concern, potentially leading to inappropriate or delayed patient management.
# *   **Increased Scan Time/Patient Burden:** Repeat sequences or entire studies due to motion prolong the time the patient spends in the scanner, increasing potential discomfort, claustrophobia, noise exposure, and in some cases, RF energy deposition (though typically well below safety limits).
# *   **Increased Contrast Load:** If a study requires IV contrast and is repeated due to motion, the patient receives an additional dose of gadolinium-based contrast agent, which carries its own set of risks (e.g., allergic reactions, nephrogenic systemic fibrosis in susceptible individuals).
#
# In summary, the ability to accurately identify motion artifacts in MRI images is a fundamental skill for anyone involved in MRI quality assurance. It requires a keen eye, a solid understanding of MRI physics, and a commitment to delivering the highest quality diagnostic images for optimal patient care.

# %% [markdown]
# ## Next Development Steps
#
# ### Phase 1: Core Functionality ✅
# - [x] Basic AI integration with Google Gemini
# - [x] MRI-specific prompt engineering
# - [x] Simple Q&A interface
#
# ### Phase 2: Enhanced Features (Planned)
# - [ ] **Image Analysis Integration**
#   - DICOM file processing
#   - Image quality metrics calculation
#   - Automated artifact detection
#
# - [ ] **Advanced QA Workflows**
#   - Structured quality checklists
#   - Protocol compliance verification
#   - Report generation
#
# - [ ] **Medical Knowledge Base**
#   - MRI physics principles
#   - Common pathologies database
#   - Quality standards reference
#
# ### Phase 3: Production Features (Future)
# - [ ] **Integration Capabilities**
#   - PACS system integration
#   - HL7 FHIR compatibility
#   - Electronic health record interfaces
#
# - [ ] **Advanced Analytics**
#   - Trend analysis across studies
#   - Predictive quality metrics
#   - Radiologist workflow optimization
#
# ### Technologies to Explore
# - **Medical Imaging**: `pydicom`, `SimpleITK`, `nibabel`
# - **AI/ML**: `scikit-learn`, `tensorflow`, `pytorch`
# - **Visualization**: `matplotlib`, `plotly`, `vtk`
# - **Medical Standards**: `pynetdicom`, `fhir.resources`
